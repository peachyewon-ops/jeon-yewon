# %% [markdown]
# ###실행1_1_1

# %% [markdown]
# ctrl 길게 누르고 M 누르기

# %% [markdown]
# ###연습해보기

# %%
#설치된 라이브러리 리스트확인
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# absl-py                                  1.4.0
# absolufy-imports                         0.3.1
# accelerate                               1.10.1
# aiofiles                                 24.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.12.15
# aiosignal                                1.4.0
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.16.5
# altair                                   5.5.0
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.11.0
# anywidget                                0.9.18
# ...

# %% [markdown]
# ###실행1_1_2

# %%
#math 모듈의 사용
import math
math.sqrt(25)
# Out:
# 5.0

# %%
#함수 리스트 보기
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
#도움말 보기
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
#모듈 별명의 사용
import math as m
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt, pi
print(pi)
sqrt(25)
# Out:
# 3.141592653589793
# 5.0

# %%
#함수 별명의 사용
from math import pi as p, sqrt as sq
print(p)
sq(9)
# Out:
# 3.141592653589793
# 3.0

# %% [markdown]
# ###실행1_1_3

# %%
#라이브러리 별명으로 import
import numpy as np
import scipy as sp
data1 = np.random.normal(0, 1, 100) #난수 생성
summary = sp.stats.describe(data1) #describe 요약통계량 (개수, 평균, 분산, 최소, 최대, 첨도, 왜도)
print(summary)
print(data1)
# Out:
# DescribeResult(nobs=np.int64(100), minmax=(np.float64(-2.613723103186903), np.float64(1.8951725159113026)), mean=np.float64(-0.1528267388076517), variance=np.float64(1.0358781383289868), skewness=np.float64(-0.232277583711871), kurtosis=np.float64(-0.3526785354608415))
# [-0.67989197  0.44170122 -1.18669204  0.54156419 -0.43182583  1.37666506
#   0.39710166  1.50841226 -1.17214599 -0.4182912  -0.46181289  1.44913988
#   0.07944542 -0.89769266 -0.50594979 -0.06027283  1.74995967 -1.35579899
#  -0.57053885  0.89870043 -1.87820206 -0.41181288  0.1463877  -0.3894434
#  -0.32249406  0.64617085 -0.52533935  0.01359157 -0.2409003  -0.13809534
#   0.16382511  1.29271275  0.42082464 -1.18313144 -1.1067383   1.15311855
#   0.69919655  0.33407331  1.45415149  0.8483347  -1.17373488 -1.48488337
#  -1.15146037  0.48973146 -0.2527636  -0.74007122 -1.60992732 -1.2823137
#  -2.49596592 -1.94687887  0.72204287  0.00988211 -1.9011935   1.71937817
# ...

# %%
#scipy의 stats 모듈을 import
import numpy as np
from scipy import stats
data1 = np.random.normal(0, 1, 100)
summary = stats.describe(data1) #더 간단하게 사용
print(summary) #난수 생성한 결과로 실행할 때마다 결과 달라짐
# Out:
# DescribeResult(nobs=np.int64(100), minmax=(np.float64(-2.2572780123983427), np.float64(2.4823173154471685)), mean=np.float64(0.17275702427229717), variance=np.float64(1.0626864707683852), skewness=np.float64(-0.19023648221174905), kurtosis=np.float64(-0.341873436856885))

# %% [markdown]
# ###실행1_2_1

# %% [markdown]
# #통계프로그래밍2
# ##1. Python 사용기초
# ###1.1 마크다운의 활용
# >글쓰기 도구인 ***마크다운***을 사용하여 더 ****구체적인 주석처리**** 가능
# >[구글](www.google.com)에서 검색

# %% [markdown]
# ###실행1_3_2

# %%
import numpy as np
help(np.random.randint) #결과 셀에 도움말 출력
# Out:
# Help on method randint in module numpy.random.mtrand:
#
# randint(low, high=None, size=None, dtype=<class 'int'>) method of numpy.random.mtrand.RandomState instance
#     randint(low, high=None, size=None, dtype=int)
#
#     Return random integers from `low` (inclusive) to `high` (exclusive).
#
#     Return random integers from the "discrete uniform" distribution of
#     the specified dtype in the "half-open" interval [`low`, `high`). If
#     `high` is None (the default), then results are from [0, `low`).
#
#     .. note::
#         New code should use the `~numpy.random.Generator.integers`
#         method of a `~numpy.random.Generator` instance instead;
#         please see the :ref:`random-quick-start`.
#
#     Parameters
#     ----------
#     low : int or array-like of ints
#         Lowest (signed) integers to be drawn from the distribution (unless
#         ``high=None``, in which case this parameter is one above the
#         *highest* such integer).
# ...

# %%
np.random.randint?

# %%
np.random.randint(1, 10, 5)
# Out:
# array([6, 8, 9, 1, 9])
